# %% [markdown]
# <a href="https://colab.research.google.com/github/dulcevalentina/fundamentosIA/blob/main/Unidad1/progrsma1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ingenieria en inteligencia artificial**
# #**fundamentos de programacion**
# ## **unidad 1**
# ### practica 1: introducion al lenguaje de programacion python
# docente: **jose gabriel rodigez rivas**
#
# alumno: ______________________
#
# numero de control:______________________________

# %%
s = None # Inicializa 's' para evitar el NameError, o asigna un valor relevante si es necesario.
x = s
x = "hola mundo"
x = True
print("el valor de x es", x) # Se corrigió 'Print' a 'print'
# Out:
# el valor de x es True

# %%
base = input("dame la base del trangulo")
altura= input("dame la altura del trangulo")
area=(int(base)*int(altura))/2
print("el area del trangulo", area)

# %%
numero1 = 40
numero2 = 40
if numero1 > numero2:
  print("el numero", numero1, "es mayor", numero2)
else:
  print("el numero", numero2, "es mayor", numero1)
# Out:
# el numero 40 es mayor 40

# %%
edad = int(input("dime tu edad"))
if edad <= 10:
  print("eres un infante")
elif edad <= 18:
    print("eres un adolecente")
elif edad <= 30:
    print("eres un adulto joven")
elif edad <= 65:
    print("eres un adulto")
else:
    print("eres un adulto mayor")
# Out:
# dime tu edad10
# eres un infante

# %%
tabla = 8
for i in range(1,11, 2):
    print( tabla, "x", i, "=", tabla*i)
# Out:
# 8 x 1 = 8
# 8 x 3 = 24
# 8 x 5 = 40
# 8 x 7 = 56
# 8 x 9 = 72

# %%
variable1 = 70
variable2 = 50
if variable1 > variable2:
  print( variable1,"es mayor que", variable2)
else:
  print(variable2,"es mayor que", variable1)
# Out:
# 70 es mayor que 50

# %%
10 > 5 and 5 > 10
# Out:
# False

# %%
edad = int(input("dame tu edad"))
if edad >=65:
  print("eres un adulto")
elif edad >=30 and edad <=65:
  print("eres un adulto joven")
elif edad >=18 and edad <=29:
  print("eres un adolecente")
elif edad >=10 and edad <= 17:
  print("eres un infante")
else :
  print("eres un adulto mayor")
# Out:
# dame tu edad15
# eres un adulto

# %%
#en este caso esta mal implementada la logica por que
#al ser if´s independiente se van a evaluar cada una de ellas
#y si ponemos por ejemplo
edad= int(input("dame tu edad"))
if edad>= 65:
  print("eres un adulto")
elif edad >= 30:
  print("eres un adulto joven")
elif edad >= 18:
  print("eres un adolcente")
elif edad >= 10:
  print("eres un infante")
else:
  print("eres un anciano")
# Out:
# dame tu edad3
# eres un anciano

# %%
tabla = int(input("que tabla de multiplicar quieres"))
limiteinicial = int(input("dame limite inicial"))
limitefinal = int(input("dame limite final"))
while limiteinicial
incrementos = int(input("dame el incremento"))
for i in range(limiteinicial, limitefinal, incrementos):
  print(tabla,"*", i, "=", tabla*i)
# Out:
#   File "/tmp/ipykernel_2132/3264659820.py", line 4
#     while limiteinicial
#                        ^
# SyntaxError: expected ':'

# %%
tabla = int(input("que tabla de multipicar quieres"))
limiteinicial = int(input(" dame limite inicial"))
limitefinal =int(input("dame limite final"))
while limiteinicial <= limiteinicial:
  print("el limite final deve ser mayor que el limite inicial")
  limitefinal = int(input("dame limite final"))
incrementos = int(input("dame el incremento"))
for i in range(limiteinicial, limitefinal,incrementos):
  print(tabla,"*", i,"=", tabla*i)
# Out:
# que tabla de multipicar quieres7
#  dame limite inicial8
# dame limite final9
# el limite final deve ser mayor que el limite inicial
# dame limite final9
# el limite final deve ser mayor que el limite inicial
# dame limite final99
# el limite final deve ser mayor que el limite inicial
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2132/206902779.py in <cell line: 0>()
#       4 while limiteinicial <= limiteinicial:
#       5   print("el limite final deve ser mayor que el limite inicial")
# ----> 6   limitefinal = int(input("dame limite final"))
#       7 incrementos = int(input("dame el incremento"))
#       8 for i in range(limiteinicial, limitefinal,incrementos):
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
# ...

# %%
numero = 1
while numero<= 5:
  print(numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # ** tema de listas¨**

# %%
alumnos =["ana", "luis","carlos", "juan"]
print(alumnos)
print(alumnos[1])
print(alumnos[3])
# Out:
# ['ana', 'luis', 'carlos', 'juan']
# luis
# juan

# %%
# modificar un valor de la lista especifico
alumnos [1]="maria luisa"
print(alumnos)
# Out:
# ['ana', 'maria luisa', 'carlos', 'juan']

# %%
#agrega metodo apped un elemento al final de la lista
alumnos.append("carla")
print(alumnos)
# Out:
# ['ana', 'maria luisa', 'carlos', 'juan', 'carla']

# %%
#el metodo insert agrega un elemento al final de la lista.
alumnos.insert(0,"cristina")
print(alumnos)
# Out:
# ['cristina', 'luis', 'cristina', 'cristina', 'cristina', 'cristina', 'cristina', 'carlos', 'juan', 'cristina']

# %%
#remove elimina un elemento especificando el valor del elemento
# debe concidir exactamente mayusculas y minusculas
alumnos.remove("ana")
alumnos.remove("ana")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1331/2263370999.py in <cell line: 0>()
#       2 # debe concidir exactamente mayusculas y minusculas
#       3 alumnos.remove("ana")
# ----> 4 alumnos.remove("ana")
#
# ValueError: list.remove(x): x not in list

# %%
print(alumnos)
# Out:
# ['luis', 'cristina', 'cristina', 'cristina', 'carlos', 'juan']

# %%
#pop elimina el elemnto o item en la posicion especificada
alumnos.pop(2)
print(alumnos)
# Out:
# ['cristina', 'luis', 'cristina', 'cristina', 'cristina', 'carlos', 'juan', 'cristina']

# %%
# del elinmina el elemennto o item en la posicion especificada
del alumnos[3]
print(alumnos)
# Out:
# ['cristina', 'luis', 'cristina', 'cristina', 'cristina', 'cristina', 'carlos', 'juan', 'cristina']

# %%
print("elemnetos en la lista de alumnos",len(alumnos))# len nos permite conocer los elementos de la lista
# Out:
# elemnetos en la lista de alumnos 8

# %%
alumnos.append("ana")
alumnos.append("ernesto")
for X in alumnos:
 print(X)
# Out:
# luis
# carlos
# juan
# ana
# ernesto
# ana
# ernesto
# ana
# ernesto

# %%
print(alumnos)
for x in alumnos:
  print(X)
  if x=="ana":
    break #breck forza a salir del ciclo siempre y cuando se cumpla
          #la condicion if
# Out:
# ['luis', 'carlos', 'juan', 'ernesto', 'ernesto', 'ernesto']
# ernesto
# ernesto
# ernesto
# ernesto
# ernesto
# ernesto

# %%
software = ["python","python y vs code","autocad","solidiWorks","java"]
print(software)
# Out:
# ['python', 'python y vs code', 'autocad', 'solidiWorks', 'java']

# %%
if"python" in software:
  print("python esta en la lista de software")
else:
  print("python no esta en la lista de sofrware")
# Out:
# python esta en la lista de software
