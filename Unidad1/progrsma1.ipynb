# %% [markdown]
# <a href="https://colab.research.google.com/github/dulcevalentina/fundamentosIA/blob/main/Unidad1/progrsma1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ingenieria en inteligencia artificial**
# #**fundamentos de programacion**
# ## **unidad 1**
# ### practica 1: introducion al lenguaje de programacion python
# docente: **jose gabriel rodigez rivas**
#
# alumno: dulce valentina villa retana
#
# numero de control:26041654

# %%
s = None # Inicializa 's' para evitar el NameError, o asigna un valor relevante si es necesario.
x = s
x = "hola mundo"
x = True
print("el valor de x es", x) # Se corrigió 'Print' a 'print'
# Out:
# el valor de x es True

# %%
base = input("dame la base del trangulo")
altura= input("dame la altura del trangulo")
area=(int(base)*int(altura))/2
print("el area del trangulo", area)

# %%
numero1 = 40
numero2 = 40
if numero1 > numero2:
  print("el numero", numero1, "es mayor", numero2)
else:
  print("el numero", numero2, "es mayor", numero1)
# Out:
# el numero 40 es mayor 40

# %%
edad = int(input("dime tu edad"))
if edad <= 10:
  print("eres un infante")
elif edad <= 18:
    print("eres un adolecente")
elif edad <= 30:
    print("eres un adulto joven")
elif edad <= 65:
    print("eres un adulto")
else:
    print("eres un adulto mayor")
# Out:
# dime tu edad10
# eres un infante

# %%
tabla = 8
for i in range(1,11, 2):
    print( tabla, "x", i, "=", tabla*i)
# Out:
# 8 x 1 = 8
# 8 x 3 = 24
# 8 x 5 = 40
# 8 x 7 = 56
# 8 x 9 = 72

# %%
variable1 = 70
variable2 = 50
if variable1 > variable2:
  print( variable1,"es mayor que", variable2)
else:
  print(variable2,"es mayor que", variable1)
# Out:
# 70 es mayor que 50

# %%
10 > 5 and 5 > 10
# Out:
# False

# %%
edad = int(input("dame tu edad"))
if edad >=65:
  print("eres un adulto")
elif edad >=30 and edad <=65:
  print("eres un adulto joven")
elif edad >=18 and edad <=29:
  print("eres un adolecente")
elif edad >=10 and edad <=17:
  print("eres un infante")
else :
  print("eres un adulto mayor")
# Out:
# dame tu edad8
# eres un adulto mayor

# %%
#en este caso esta mal implementada la logica por que
#al ser if´s independiente se van a evaluar cada una de ellas
#y si ponemos por ejemplo
edad= int(input("dame tu edad"))
if edad>= 65:
  print("eres un adulto")
elif edad >= 30:
  print("eres un adulto joven")
elif edad >= 18:
  print("eres un adolcente")
elif edad >= 10:
  print("eres un infante")
else:
  print("eres un anciano")
# Out:
# dame tu edad8
# eres un anciano

# %%
tabla = int(input("que tabla de multipicar quieres"))
limiteinicial = int(input(" dame limite inicial"))
limitefinal =int(input("dame limite final"))
while limiteinicial <= limiteinicial:
  print("el limite final deve ser mayor que el limite inicial")
  limitefinal = int(input("dame limite final"))
incrementos = int(input("dame el incremento"))
for i in range(limiteinicial, limitefinal,incrementos):
  print(tabla,"*", i,"=", tabla*i)

# %%
numero = 1
while numero<= 5:
  print(numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # **tema de listas**

# %%
alumnos =["Ana", "Luis","Carlos","Juan"]
print(alumnos)
print(alumnos[0])
print(alumnos[3])
# Out:
# ['Ana', 'Luis', 'Carlos', 'Juan']
# Ana
# Juan

# %%
# modificar un valor de la lista especifico
alumnos [1]="maria luisa"
print(alumnos)
# Out:
# ['ana', 'maria luisa', 'carlos', 'juan']

# %%
#agrega metodo apped un elemento al final de la lista
alumnos.append("Karla")
print(alumnos)
# Out:
# ['ana', 'luis', 'carlos', 'juan', 'karla']

# %%
#el metodo insert agrega un elemento al final de la lista.
alumnos.insert(0,"Cristina")
print(alumnos)
# Out:
# ['cristina', 'ana', 'luis', 'carlos', 'juan', 'karla']

# %%
#remove elimina un elemento especificando el valor del elemento
# debe concidir exactamente mayusculas y minusculas
alumnos.remove("Ana")
print(alumnos)
# Out:
# ['Luis', 'Carlos', 'Juan']

# %%
#pop elimina el elemnto o item en la posicion especificada
alumnos.pop(2)
print(alumnos)
# Out:
# ['Luis', 'Carlos']

# %%
# del elinmina el elemennto o item en la posicion especificada
del alumnos[1]
print(alumnos)
# Out:
# ['Luis']

# %%
print("elemnetos en la lista de alumnos",len(alumnos))
# len nos permite conocer los elementos de la lista
# Out:
# elemnetos en la lista de alumnos 1

# %%
alumnos.append("ana")
alumnos.append("ernesto")
for X in alumnos:
 print(X)
# Out:
# Luis
# ana
# ernesto

# %%
print(alumnos)
for x in alumnos:
  print(X)
  if x=="ana":
    break #breck forza a salir del ciclo siempre y cuando se cumpla
          #la condicion if
# Out:
# ['Luis', 'ana', 'ernesto']
# ernesto
# ernesto

# %%
software = ["Python", "Python y Vs code", "Autocad","SolidiWorks","Java"]
print(software)
# Out:
# ['Python', 'Python y Vs code', 'Autocad', 'SolidiWorks', 'Java']

# %%
if "Python" in software:
  print("Python esta en la lista de software")
else:
  print("Python no esta en la lista de sofrware")
# Out:
# Python esta en la lista de software

# %%
for i in range( len(software)):
 print(software[i])

print("enlistar otra vez la lista de software")
for x in software:
  print(x)
# Out:
# Python
# Python y Vs code
# Autocad
# SolidiWorks
# Java
# enlistar otra vez la lista de software
# Python
# Python y Vs code
# Autocad
# SolidiWorks
# Java

# %% [markdown]
# ## **sistema de prestamoa version 1**

# %%
for x in software:
    print(x)

#SISTEMA DE PRÉSTAMOS
# Versión 1 Programación basica y uso de listas
# Lista de alumnos activos en el sistema
alumnos = ["26040200", "26040201", "26040202", "26040203", "26040204"]
# Cada valor en la lista de computadoras tiene su lista correspondiente con el aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]

aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3", "LC3"]

software = ["Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB", "Python, VS Code"]

estados = ["Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada",
           "Disponible", "Prestada", "Reservada", "Mantenimiento"]

# MENÚ PRINCIPAL
# Usamos un ciclo While que se repetira indefinidamente hasta que el usuario teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
    print("\n-------------------------")
    print(" SISTEMA DE PRÉSTAMOS")
    print("-------------------------")
    print("1. Consultar computadoras")
    print("2. Buscar por software")
    print("3. Solicitar préstamo")
    print("4. Devolver computadora")
    print("5. Crear reservación")
    print("6. Agregar computadora")
    print("7. Salir")
    print("-------------------------")
    opcion = int(input("Seleccione una opción: "))

    #1. Consultar computadoras
    # si el usuario selecciono la opcion 1 se hace un ciclo (for) que recorre
    #toda la lista de computadoras e imprime los valores de las demás listas
    if opcion == 1:
        print("\n--- COMPUTADORAS ---")
        for i in range(len(computadoras)):
            print("Aula:", aulas[i])
            print("ID:", computadoras[i])
            print("Software:", software[i])
            print("Estado:", estados[i])

    # 2. Buscar por software
    elif opcion == 2:
        programa = input("\nIngrese el software que desea buscar: ")
        print("\n--- RESULTADOS ---")
        encontrado = False
        for i in range(len(computadoras)):
            # la funcion (lower) convierte a minuscula el texto, de esta forma
            # nos aseguramos que el texto a buscar y la informacion de las listas
            # este en minuscula y no tengamos problema de que no encuentre un programa
            # porque este escrito de forma diferente usando mayusculas y minusculas
            if programa.lower() in software[i].lower():
                print("ID:", computadoras[i])
                print("Aula:", aulas[i])
                print("Software:", software[i])
                print("Estado:", estados[i])
                encontrado = True

        if not encontrado:
            print("No se encontraron computadoras con ese software.")

    # 3. Solicitar préstamo
    elif opcion == 3:
        print("\n--- SOLICITAR PRÉSTAMO ---")
        num_control = input(" \nIngrese el número de control: ")
        encontrado1 = False
        # Verificar si existe el alumno en la lista o BD
        if num_control in alumnos:
            # Si existe, continuamos con el procedimiento
            encontrado1 = True
            id_computadora = input("Ingrese el ID de la computadora: ")
            encontrado2 = False
            for i in range(len(computadoras)):
                if computadoras[i] == id_computadora:
                    encontrado2 = True
                    if estados[i] == "Disponible":
                        estados[i] = "Prestada"
                        print("Préstamo registrado correctamente.")
                        print("Computadora:", computadoras[i])
                        print("Aula:", aulas[i])
                    else:
                        print("La computadora no está disponible.")
            if encontrado2 == False:
                print("La computadora no existe.")
        if encontrado1 == False:
            print("El alumno no existe.")
# Out:
# Python, VS Code
# Python, Java, VS Code
# AutoCAD, MATLAB
# Python, VS Code
# Python, Java, VS Code
# AutoCAD, MATLAB
# Python, VS Code
# Python, Java, VS Code
# AutoCAD, MATLAB
# Python, VS Code
#
# -------------------------
#  SISTEMA DE PRÉSTAMOS
# -------------------------
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservación
# 6. Agregar computadora
# 7. Salir
# -------------------------
# Seleccione una opción: 6
#
# -------------------------
#  SISTEMA DE PRÉSTAMOS
# -------------------------
# 1. Consultar computadoras
# 2. Buscar por software
# 3. Solicitar préstamo
# 4. Devolver computadora
# 5. Crear reservación
# 6. Agregar computadora
# 7. Salir
# -------------------------
# Seleccione una opción: 1
#
# --- COMPUTADORAS ---
# Aula: LC1
# ID: PC-LC1-01
# Software: Python, VS Code
# Estado: Disponible
# Aula: LC1
# ID: PC-LC1-02
# Software: Python, Java, VS Code
# Estado: Prestada
# Aula: LC1
# ...

# %%
# 3. Solicitar préstamo
elif opcion == 3:
    print("\n--- SOLICITAR PRÉSTAMO ---")
    num_control = input("\nIngrese el número de control: ")
    encontrado1 = False

    # Verificar si existe el alumno en la lista o BD
    if num_control in alumnos:
        # Si existe, continuamos con el procedimiento
        encontrado1 = True
        id_computadora = input("Ingrese el ID de la computadora: ")
        encontrado2 = False

        for i in range(len(computadoras)):
            if computadoras[i] == id_computadora:
                encontrado2 = True
                if estados[i] == "Disponible":
                    estados[i] = "Prestada"
                    print("Préstamo registrado correctamente.")
                    print("Computadora:", computadoras[i])
                    print("Aula:", aulas[i])
                else:
                    print("La computadora no está disponible.")
                break

        # Debe estar ALINEADO con el 'for', no dentro de él
        if encontrado2 == False:
            print("La computadora no existe.")

    # Debe estar ALINEADO con el 'if num_control in alumnos:'
    if encontrado1 == False:
        print("El alumno no existe.")
